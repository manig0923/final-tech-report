# %% [markdown]
# <a href="https://colab.research.google.com/github/manig0923/final-tech-report/blob/main/02_modeling_and_decision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Week 2 Checkpoints </h1>

# %% [markdown]
# <h2> Part C </h2>
